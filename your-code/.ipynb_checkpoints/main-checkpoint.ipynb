# %% [markdown]
# # Working with RSS Feeds Lab
#
# Complete the following set of exercises to solidify your knowledge of parsing RSS feeds and extracting information from them.

# %%
import feedparser

# %% [markdown]
# ### 1. Use feedparser to parse the following RSS feed URL.

# %%
url = 'http://feeds.feedburner.com/oreilly/radar/atom'

# %%
oreilly = feedparser.parse(url)

# %% [markdown]
# ### 2. Obtain a list of components (keys) that are available for this feed.

# %%
oreilly.keys()
# Out:
# dict_keys(['bozo', 'entries', 'feed', 'headers', 'updated', 'updated_parsed', 'href', 'status', 'encoding', 'version', 'namespaces'])

# %% [markdown]
# ### 3. Obtain a list of components (keys) that are available for the *feed* component of this RSS feed.

# %%
oreilly.feed.keys()
# Out:
# dict_keys(['title', 'title_detail', 'links', 'link', 'subtitle', 'subtitle_detail', 'updated', 'updated_parsed', 'language', 'sy_updateperiod', 'sy_updatefrequency', 'generator_detail', 'generator'])

# %% [markdown]
# ### 4. Extract and print the feed title, subtitle, author, and link.

# %%
print(oreilly.feed.title)
print('')
print(oreilly.feed.subtitle)
print('')
print(oreilly.feed.link)
#there is no author available for the whole feed
# Out:
# Radar
#
# Now, next, and beyond: Tracking need-to-know trends at the intersection of business and technology
#
# https://www.oreilly.com/radar

# %% [markdown]
# ### 5. Count the number of entries that are contained in this RSS feed.

# %%
print(len(oreilly.entries))
# Out:
# 15

# %% [markdown]
# ### 6. Obtain a list of components (keys) available for an entry.
#
# *Hint: Remember to index first before requesting the keys*

# %%
oreilly.entries[0].keys()
# Out:
# dict_keys(['title', 'title_detail', 'links', 'link', 'comments', 'published', 'published_parsed', 'authors', 'author', 'author_detail', 'tags', 'id', 'guidislink', 'summary', 'summary_detail', 'content', 'wfw_commentrss', 'slash_comments'])

# %% [markdown]
# ### 7. Extract a list of entry titles.

# %%
titles = []
for i in range (0,15):
    title = oreilly.entries[i].title
    titles.append(title)
    i+=1
titles
# Out:
# ['Healthy Data',
#  'Formal Informal Languages',
#  'Radar Trends to Watch: November 2022',
#  'What We Learned Auditing Sophisticated AI for Bias',
#  'The Collaborative Metaverse',
#  'What Is Hyperautomation?',
#  'Radar Trends to Watch: October 2022',
#  'The Problem with Intelligence',
#  'Radar Trends to Watch: September 2022',
#  'Ad Networks and Content Marketing',
#  'On Technique',
#  'Scaling False Peaks',
#  'The Metaverse Is Not a Place',
#  'Radar Trends to Watch: August 2022',
#  'SQL: The Universal Solvent for REST APIs']

# %% [markdown]
# ### 8. Calculate the percentage of "Four short links" entry titles.

# %%
#Zero, Four short links stopped being published on December 14th, 2020 (two years ago!)

# %% [markdown]
# ### 9. Create a Pandas data frame from the feed's entries.

# %%
import pandas as pd

# %%
df = pd.DataFrame(oreilly.entries)
df
# Out:
#            author              author_detail                      authors  \
# 0   Mike Loukides  {'name': 'Mike Loukides'}  [{'name': 'Mike Loukides'}]
# 1   Mike Loukides  {'name': 'Mike Loukides'}  [{'name': 'Mike Loukides'}]
# 2   Mike Loukides  {'name': 'Mike Loukides'}  [{'name': 'Mike Loukides'}]
# 3    Patrick Hall   {'name': 'Patrick Hall'}   [{'name': 'Patrick Hall'}]
# 4   Mike Loukides  {'name': 'Mike Loukides'}  [{'name': 'Mike Loukides'}]
# 5   Mike Loukides  {'name': 'Mike Loukides'}  [{'name': 'Mike Loukides'}]
# 6   Mike Loukides  {'name': 'Mike Loukides'}  [{'name': 'Mike Loukides'}]
# 7   Mike Loukides  {'name': 'Mike Loukides'}  [{'name': 'Mike Loukides'}]
# 8   Mike Loukides  {'name': 'Mike Loukides'}  [{'name': 'Mike Loukides'}]
# 9      Q McCallum     {'name': 'Q McCallum'}     [{'name': 'Q McCallum'}]
# 10  Mike Loukides  {'name': 'Mike Loukides'}  [{'name': 'Mike Loukides'}]
# 11  Kevlin Henney  {'name': 'Kevlin Henney'}  [{'name': 'Kevlin Henney'}]
# 12   Tim O’Reilly   {'name': 'Tim O’Reilly'}   [{'name': 'Tim O’Reilly'}]
# 13  Mike Loukides  {'name': 'Mike Loukides'}  [{'name': 'Mike Loukides'}]
# 14      Jon Udell      {'name': 'Jon Udell'}      [{'name': 'Jon Udell'}]
#
#                                              comments  \
# 0   https://www.oreilly.com/radar/healthy-data/#re...
# 1   https://www.oreilly.com/radar/formal-informal-...
# 2   https://www.oreilly.com/radar/radar-trends-to-...
# 3   https://www.oreilly.com/radar/what-we-learned-...
# 4   https://www.oreilly.com/radar/the-collaborativ...
# 5   https://www.oreilly.com/radar/what-is-hyperaut...
# 6   https://www.oreilly.com/radar/radar-trends-to-...
# 7   https://www.oreilly.com/radar/the-problem-with...
# 8   https://www.oreilly.com/radar/radar-trends-to-...
# 9   https://www.oreilly.com/radar/ad-networks-and-...
# 10  https://www.oreilly.com/radar/on-technique/#re...
# 11  https://www.oreilly.com/radar/scaling-false-pe...
# 12  https://www.oreilly.com/radar/the-metaverse-is...
# 13  https://www.oreilly.com/radar/radar-trends-to-...
# 14  https://www.oreilly.com/radar/sql-the-universa...
#
#                                               content  guidislink  \
# 0   [{'type': 'text/html', 'language': None, 'base...       False
# 1   [{'type': 'text/html', 'language': None, 'base...       False
# 2   [{'type': 'text/html', 'language': None, 'base...       False
# 3   [{'type': 'text/html', 'language': None, 'base...       False
# 4   [{'type': 'text/html', 'language': None, 'base...       False
# 5   [{'type': 'text/html', 'language': None, 'base...       False
# 6   [{'type': 'text/html', 'language': None, 'base...       False
# 7   [{'type': 'text/html', 'language': None, 'base...       False
# 8   [{'type': 'text/html', 'language': None, 'base...       False
# 9   [{'type': 'text/html', 'language': None, 'base...       False
# 10  [{'type': 'text/html', 'language': None, 'base...       False
# 11  [{'type': 'text/html', 'language': None, 'base...       False
# 12  [{'type': 'text/html', 'language': None, 'base...       False
# 13  [{'type': 'text/html', 'language': None, 'base...       False
# 14  [{'type': 'text/html', 'language': None, 'base...       False
#
#                                         id  \
# 0   https://www.oreilly.com/radar/?p=14784
# 1   https://www.oreilly.com/radar/?p=14772
# 2   https://www.oreilly.com/radar/?p=14760
# 3   https://www.oreilly.com/radar/?p=14754
# 4   https://www.oreilly.com/radar/?p=14750
# 5   https://www.oreilly.com/radar/?p=14733
# 6   https://www.oreilly.com/radar/?p=14726
# 7   https://www.oreilly.com/radar/?p=14718
# 8   https://www.oreilly.com/radar/?p=14700
# 9   https://www.oreilly.com/radar/?p=14688
# 10  https://www.oreilly.com/radar/?p=14669
# 11  https://www.oreilly.com/radar/?p=14661
# 12  https://www.oreilly.com/radar/?p=14641
# 13  https://www.oreilly.com/radar/?p=14631
# 14  https://www.oreilly.com/radar/?p=14612
#
#                                                  link  \
# 0         https://www.oreilly.com/radar/healthy-data/
# 1   https://www.oreilly.com/radar/formal-informal-...
# 2   https://www.oreilly.com/radar/radar-trends-to-...
# 3   https://www.oreilly.com/radar/what-we-learned-...
# 4   https://www.oreilly.com/radar/the-collaborativ...
# 5   https://www.oreilly.com/radar/what-is-hyperaut...
# 6   https://www.oreilly.com/radar/radar-trends-to-...
# 7   https://www.oreilly.com/radar/the-problem-with...
# 8   https://www.oreilly.com/radar/radar-trends-to-...
# 9   https://www.oreilly.com/radar/ad-networks-and-...
# 10        https://www.oreilly.com/radar/on-technique/
# 11  https://www.oreilly.com/radar/scaling-false-pe...
# 12  https://www.oreilly.com/radar/the-metaverse-is...
# 13  https://www.oreilly.com/radar/radar-trends-to-...
# 14  https://www.oreilly.com/radar/sql-the-universa...
#
#                                                 links  \
# 0   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 1   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 2   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 3   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 4   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 5   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 6   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 7   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 8   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 9   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 10  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 11  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 12  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 13  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 14  [{'rel': 'alternate', 'type': 'text/html', 'hr...
#
#                           published                       published_parsed  \
# 0   Tue, 15 Nov 2022 15:18:53 +0000  (2022, 11, 15, 15, 18, 53, 1, 319, 0)
# 1   Tue, 08 Nov 2022 11:58:09 +0000    (2022, 11, 8, 11, 58, 9, 1, 312, 0)
# 2   Tue, 01 Nov 2022 11:15:57 +0000   (2022, 11, 1, 11, 15, 57, 1, 305, 0)
# 3   Tue, 18 Oct 2022 11:14:23 +0000  (2022, 10, 18, 11, 14, 23, 1, 291, 0)
# 4   Wed, 12 Oct 2022 20:01:45 +0000   (2022, 10, 12, 20, 1, 45, 2, 285, 0)
# 5   Tue, 11 Oct 2022 10:59:21 +0000  (2022, 10, 11, 10, 59, 21, 1, 284, 0)
# 6   Tue, 04 Oct 2022 11:15:42 +0000   (2022, 10, 4, 11, 15, 42, 1, 277, 0)
# 7   Tue, 13 Sep 2022 11:21:40 +0000   (2022, 9, 13, 11, 21, 40, 1, 256, 0)
# 8   Tue, 06 Sep 2022 11:21:09 +0000     (2022, 9, 6, 11, 21, 9, 1, 249, 0)
# 9   Tue, 16 Aug 2022 11:21:21 +0000   (2022, 8, 16, 11, 21, 21, 1, 228, 0)
# 10  Tue, 09 Aug 2022 11:12:22 +0000    (2022, 8, 9, 11, 12, 22, 1, 221, 0)
# 11  Thu, 04 Aug 2022 11:12:44 +0000    (2022, 8, 4, 11, 12, 44, 3, 216, 0)
# 12  Tue, 02 Aug 2022 18:38:46 +0000    (2022, 8, 2, 18, 38, 46, 1, 214, 0)
# 13  Tue, 02 Aug 2022 11:18:24 +0000    (2022, 8, 2, 11, 18, 24, 1, 214, 0)
# 14  Tue, 19 Jul 2022 11:16:39 +0000   (2022, 7, 19, 11, 16, 39, 1, 200, 0)
#
#    slash_comments                                            summary  \
# 0               0  This summer, we started asking about “technica...
# 1               0  We’ve all been impressed by the generative art...
# 2               0  Maintaining a separate category for AI is gett...
# 3               0  A recently passed law in New York City require...
# 4               0  We want to congratulate Dylan Field on his sta...
# 5               0  Gartner has anointed “Hyperautomation” one of ...
# 6               0  September was a busy month. In addition to con...
# 7               0  Projects like OpenAI’s DALL-E and DeepMind’s G...
# 8               0  It’s hardly news to talk about the AI developm...
# 9               0  In a recent Radar piece, I explored N-sided ma...
# 10              0  In a previous article, I wrote about how model...
# 11              0  Humans are notoriously poor at judging distanc...
# 12              0  The metaphors we use to describe new technolog...
# 13              0  The large model train keeps rolling on. This m...
# 14              0  Data scientists working in Python or R typical...
#
#                                        summary_detail  \
# 0   {'type': 'text/html', 'language': None, 'base'...
# 1   {'type': 'text/html', 'language': None, 'base'...
# 2   {'type': 'text/html', 'language': None, 'base'...
# 3   {'type': 'text/html', 'language': None, 'base'...
# 4   {'type': 'text/html', 'language': None, 'base'...
# 5   {'type': 'text/html', 'language': None, 'base'...
# 6   {'type': 'text/html', 'language': None, 'base'...
# 7   {'type': 'text/html', 'language': None, 'base'...
# 8   {'type': 'text/html', 'language': None, 'base'...
# 9   {'type': 'text/html', 'language': None, 'base'...
# 10  {'type': 'text/html', 'language': None, 'base'...
# 11  {'type': 'text/html', 'language': None, 'base'...
# 12  {'type': 'text/html', 'language': None, 'base'...
# 13  {'type': 'text/html', 'language': None, 'base'...
# 14  {'type': 'text/html', 'language': None, 'base'...
#
#                                                  tags  \
# 0   [{'term': 'Data', 'scheme': None, 'label': Non...
# 1   [{'term': 'Programming', 'scheme': None, 'labe...
# 2   [{'term': 'Radar Trends', 'scheme': None, 'lab...
# 3   [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 4   [{'term': 'Metaverse', 'scheme': None, 'label'...
# 5   [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 6   [{'term': 'Radar Trends', 'scheme': None, 'lab...
# 7   [{'term': 'Artificial Intelligence', 'scheme':...
# 8   [{'term': 'Radar Trends', 'scheme': None, 'lab...
# 9   [{'term': 'Operations', 'scheme': None, 'label...
# 10  [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 11  [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 12  [{'term': 'Metaverse', 'scheme': None, 'label'...
# 13  [{'term': 'Radar Trends', 'scheme': None, 'lab...
# 14  [{'term': 'Data', 'scheme': None, 'label': Non...
#
#                                                 title  \
# 0                                        Healthy Data
# 1                           Formal Informal Languages
# 2                Radar Trends to Watch: November 2022
# 3   What We Learned Auditing Sophisticated AI for ...
# 4                         The Collaborative Metaverse
# 5                            What Is Hyperautomation?
# 6                 Radar Trends to Watch: October 2022
# 7                       The Problem with Intelligence
# 8               Radar Trends to Watch: September 2022
# 9                   Ad Networks and Content Marketing
# 10                                       On Technique
# 11                                Scaling False Peaks
# 12                       The Metaverse Is Not a Place
# 13                 Radar Trends to Watch: August 2022
# 14           SQL: The Universal Solvent for REST APIs
#
#                                          title_detail  \
# 0   {'type': 'text/plain', 'language': None, 'base...
# 1   {'type': 'text/plain', 'language': None, 'base...
# 2   {'type': 'text/plain', 'language': None, 'base...
# 3   {'type': 'text/plain', 'language': None, 'base...
# 4   {'type': 'text/plain', 'language': None, 'base...
# 5   {'type': 'text/plain', 'language': None, 'base...
# 6   {'type': 'text/plain', 'language': None, 'base...
# 7   {'type': 'text/plain', 'language': None, 'base...
# 8   {'type': 'text/plain', 'language': None, 'base...
# 9   {'type': 'text/plain', 'language': None, 'base...
# 10  {'type': 'text/plain', 'language': None, 'base...
# 11  {'type': 'text/plain', 'language': None, 'base...
# 12  {'type': 'text/plain', 'language': None, 'base...
# 13  {'type': 'text/plain', 'language': None, 'base...
# 14  {'type': 'text/plain', 'language': None, 'base...
#
#                                        wfw_commentrss
# 0    https://www.oreilly.com/radar/healthy-data/feed/
# 1   https://www.oreilly.com/radar/formal-informal-...
# 2   https://www.oreilly.com/radar/radar-trends-to-...
# 3   https://www.oreilly.com/radar/what-we-learned-...
# 4   https://www.oreilly.com/radar/the-collaborativ...
# 5   https://www.oreilly.com/radar/what-is-hyperaut...
# 6   https://www.oreilly.com/radar/radar-trends-to-...
# 7   https://www.oreilly.com/radar/the-problem-with...
# 8   https://www.oreilly.com/radar/radar-trends-to-...
# 9   https://www.oreilly.com/radar/ad-networks-and-...
# 10   https://www.oreilly.com/radar/on-technique/feed/
# 11  https://www.oreilly.com/radar/scaling-false-pe...
# 12  https://www.oreilly.com/radar/the-metaverse-is...
# 13  https://www.oreilly.com/radar/radar-trends-to-...
# 14  https://www.oreilly.com/radar/sql-the-universa...

# %% [markdown]
# ### 10. Count the number of entries per author and sort them in descending order.

# %%
authors = df.groupby('author', as_index=False).agg({'title':'count'})
authors.columns = ['author', 'entries']
authors.sort_values('entries', ascending=False)
# Out:
#           author  entries
# 2  Mike Loukides       10
# 0      Jon Udell        1
# 1  Kevlin Henney        1
# 3   Patrick Hall        1
# 4     Q McCallum        1
# 5   Tim O’Reilly        1

# %% [markdown]
# ### 11. Add a new column to the data frame that contains the length (number of characters) of each entry title. Return a data frame that contains the title, author, and title length of each entry in descending order (longest title length at the top).

# %%
df['title_length']=df['title'].apply(len)
df2= pd.DataFrame(df, columns=['title', 'author', 'title_length'])
df2 = df2.sort_values(by='title_length', ascending=False)
df2
# Out:
#                                                 title         author  \
# 3   What We Learned Auditing Sophisticated AI for ...   Patrick Hall
# 14           SQL: The Universal Solvent for REST APIs      Jon Udell
# 8               Radar Trends to Watch: September 2022  Mike Loukides
# 2                Radar Trends to Watch: November 2022  Mike Loukides
# 6                 Radar Trends to Watch: October 2022  Mike Loukides
# 13                 Radar Trends to Watch: August 2022  Mike Loukides
# 9                   Ad Networks and Content Marketing     Q McCallum
# 7                       The Problem with Intelligence  Mike Loukides
# 12                       The Metaverse Is Not a Place   Tim O’Reilly
# 4                         The Collaborative Metaverse  Mike Loukides
# 1                           Formal Informal Languages  Mike Loukides
# 5                            What Is Hyperautomation?  Mike Loukides
# 11                                Scaling False Peaks  Kevlin Henney
# 0                                        Healthy Data  Mike Loukides
# 10                                       On Technique  Mike Loukides
#
#     title_length
# 3             50
# 14            40
# 8             37
# 2             36
# 6             35
# 13            34
# 9             33
# 7             29
# 12            28
# 4             27
# 1             25
# 5             24
# 11            19
# 0             12
# 10            12

# %% [markdown]
# ### 12. Create a list of entry titles whose summary includes the phrase "machine learning."

# %%
summaries = []
for i in range (0,15):
    summary = oreilly.entries[i].summary
    summaries.append(summary)
    i+=1
summaries

machine_learning = []
for i in range(0,15):
    if 'machine learning' in summaries[i]:
        machine_learning.append(oreilly.entries[i].title)
        i+=1
machine_learning
# Out:
# ['Radar Trends to Watch: October 2022']
